# %% [markdown]
# # pandas

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=pd.date_range('20250717', periods=6), columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2025-07-17 -0.208116  1.678700  0.105290  0.957822
# 2025-07-18  2.285614  0.252923  0.405199 -1.602127
# 2025-07-19 -0.714340  1.955761  1.141218  0.657136
# 2025-07-20 -0.653365  2.099525 -0.242964 -1.102684
# 2025-07-21  0.585015 -1.329721  0.916533  0.449872
# 2025-07-22  0.925813  1.618102 -1.821646  0.108501

# %%
df2 = df.copy()
df2['E'] = ['one', 'one', 'two', 'three', 'four', 'three']
df2
# Out:
#                    A         B         C         D      E
# 2025-07-17 -0.208116  1.678700  0.105290  0.957822    one
# 2025-07-18  2.285614  0.252923  0.405199 -1.602127    one
# 2025-07-19 -0.714340  1.955761  1.141218  0.657136    two
# 2025-07-20 -0.653365  2.099525 -0.242964 -1.102684  three
# 2025-07-21  0.585015 -1.329721  0.916533  0.449872   four
# 2025-07-22  0.925813  1.618102 -1.821646  0.108501  three

# %%
df2[df2['E'].isin(['two', 'four'])]
# Out:
#                    A         B         C         D     E
# 2025-07-19 -0.714340  1.955761  1.141218  0.657136   two
# 2025-07-21  0.585015 -1.329721  0.916533  0.449872  four

# %%
df2.shift(1)
# Out:
#                    A         B         C         D      E
# 2025-07-17       NaN       NaN       NaN       NaN   None
# 2025-07-18 -0.208116  1.678700  0.105290  0.957822    one
# 2025-07-19  2.285614  0.252923  0.405199 -1.602127    one
# 2025-07-20 -0.714340  1.955761  1.141218  0.657136    two
# 2025-07-21 -0.653365  2.099525 -0.242964 -1.102684  three
# 2025-07-22  0.585015 -1.329721  0.916533  0.449872   four

# %%
df = pd.DataFrame(np.random.randn(2, 2))
df
# Out:
#           0         1
# 0 -1.243000 -1.345521
# 1  0.612792 -0.842152

# %%
pd.concat([df, df])
# Out:
#           0         1
# 0 -1.243000 -1.345521
# 1  0.612792 -0.842152
# 0 -1.243000 -1.345521
# 1  0.612792 -0.842152

# %%
df = pd.DataFrame(np.random.randn(8, 4), columns=['A', 'B', 'C', 'D'])
df
# Out:
#           A         B         C         D
# 0 -1.010810  0.103829  0.697129 -0.561206
# 1 -1.405811 -0.918326 -0.396465 -0.721326
# 2 -1.692895  2.026537  1.093125  1.151086
# 3  1.801739  1.665731  0.790812 -0.861060
# 4  1.072657  0.255862 -1.841954 -0.294285
# 5 -0.893896  0.308552 -0.906205 -2.151230
# 6 -1.232527  0.269852 -0.854796  0.338543
# 7  1.171554 -0.617479 -0.340995 -0.385319

# %%
df.groupby('A').sum()
# Out:
#                   B         C         D
# A
# -1.692895  2.026537  1.093125  1.151086
# -1.405811 -0.918326 -0.396465 -0.721326
# -1.232527  0.269852 -0.854796  0.338543
# -1.010810  0.103829  0.697129 -0.561206
# -0.893896  0.308552 -0.906205 -2.151230
#  1.072657  0.255862 -1.841954 -0.294285
#  1.171554 -0.617479 -0.340995 -0.385319
#  1.801739  1.665731  0.790812 -0.861060

# %%
df.groupby('A')
