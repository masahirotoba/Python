# %% [markdown]
# # pandas

# %%
import numpy as np
import pandas as pd

# %%
s = pd.Series([1, 2, 3])
s
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
s.sum()
# Out:
# np.int64(6)

# %%
s = pd.Series([4, 5, 6])
s
# Out:
# 0    4
# 1    5
# 2    6
# dtype: int64

# %%
df = pd.DataFrame({'A':[1, 2], 'B':[3,4]})
df
# Out:
#    A  B
# 0  1  3
# 1  2  4

# %%
df = pd.DataFrame({'日付':['4月', '5月'], '数値':[10, 20]})
df
# Out:
#    日付  数値
# 0  4月  10
# 1  5月  20
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# /usr/local/lib/python3.11/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   plt.savefig(
# /usr/local/lib/python3.11/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 20516 (\N{CJK UNIFIED IDEOGRAPH-5024}) missing from font(s) DejaVu Sans.
#   plt.savefig(
# from matplotlib import pyplot as plt
# df['数値'].plot(kind='hist', bins=20, title='数値')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# ...

# %%
df = pd.DataFrame(np.random.randn(6, 4))
df
# Out:
#           0         1         2         3
# 0  0.477956  1.935527 -1.037369  1.653346
# 1 -0.582888 -1.693513 -0.107792  1.803237
# 2 -0.600253  0.739496 -0.753518  1.380700
# 3 -1.071170 -0.610070 -0.548951  0.760770
# 4 -0.326065 -0.527191 -1.262971 -2.599370
# 5  0.503459 -0.642825 -1.466293 -0.605478

# %%
df = pd.DataFrame(np.random.randn(6, 4))
df
# Out:
#           0         1         2         3
# 0  0.757718  0.578070  0.724111  0.458967
# 1 -0.015267 -0.504692  0.535882 -1.698054
# 2 -0.110617 -0.420182 -0.637712 -0.110551
# 3  1.252002 -1.029195  0.393190  0.537800
# 4  1.523232 -1.265333  1.567172 -0.480950
# 5 -0.898244  0.654140 -1.126591 -0.466220

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=pd.date_range('20250717', periods=6))
df
# Out:
#                    0         1         2         3
# 2025-07-17  1.596344  0.116909  2.143241  0.419026
# 2025-07-18 -0.072287  0.210132  1.134706 -0.419466
# 2025-07-19 -0.454423  1.187039  0.769467  2.721506
# 2025-07-20 -0.422478  2.637669  0.181443 -0.502806
# 2025-07-21  0.451540 -0.676202 -0.375171  0.992324
# 2025-07-22  0.167478  0.518479 -0.104077 -1.381962

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=pd.date_range('20250717', periods=6), columns = ['A', 'B', 'C', 'D'])
df
# Out:
#                    A         B         C         D
# 2025-07-17  1.332554 -0.208895 -1.371553 -0.986204
# 2025-07-18 -0.505456  1.173234 -2.788813  0.193987
# 2025-07-19 -0.136465  1.595597 -0.486425  0.242111
# 2025-07-20  0.725907  0.323068 -0.401490  2.567489
# 2025-07-21  0.151433  1.252990  0.830669  0.802868
# 2025-07-22  1.404012 -0.124493  0.029115  0.797099

# %%
df.head(1)
# Out:
#                    A         B         C         D
# 2025-07-17  1.332554 -0.208895 -1.371553 -0.986204

# %%
df.tail(3)
# Out:
#                    A         B         C         D
# 2025-07-20  0.725907  0.323068 -0.401490  2.567489
# 2025-07-21  0.151433  1.252990  0.830669  0.802868
# 2025-07-22  1.404012 -0.124493  0.029115  0.797099

# %%
df.index
# Out:
# DatetimeIndex(['2025-07-17', '2025-07-18', '2025-07-19', '2025-07-20',
#                '2025-07-21', '2025-07-22'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.values
# Out:
# array([[ 1.3325544 , -0.20889513, -1.37155283, -0.98620366],
#        [-0.50545583,  1.17323383, -2.78881335,  0.19398684],
#        [-0.13646508,  1.59559697, -0.48642497,  0.24211059],
#        [ 0.72590693,  0.32306823, -0.40149045,  2.5674888 ],
#        [ 0.151433  ,  1.25299035,  0.830669  ,  0.80286796],
#        [ 1.40401185, -0.12449266,  0.02911455,  0.79709897]])

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.495331  0.668584 -0.698083  0.602892
# std    0.787250  0.771217  1.250870  1.162750
# min   -0.505456 -0.208895 -2.788813 -0.986204
# 25%   -0.064491 -0.012602 -1.150271  0.206018
# 50%    0.438670  0.748151 -0.443958  0.519605
# 75%    1.180893  1.233051 -0.078537  0.801426
# max    1.404012  1.595597  0.830669  2.567489

# %%
df.sort_values(by='B')
# Out:
#                    A         B         C         D
# 2025-07-17  1.332554 -0.208895 -1.371553 -0.986204
# 2025-07-22  1.404012 -0.124493  0.029115  0.797099
# 2025-07-20  0.725907  0.323068 -0.401490  2.567489
# 2025-07-18 -0.505456  1.173234 -2.788813  0.193987
# 2025-07-21  0.151433  1.252990  0.830669  0.802868
# 2025-07-19 -0.136465  1.595597 -0.486425  0.242111

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2025-07-17  1.332554 -0.208895 -1.371553 -0.986204
# 2025-07-18 -0.505456  1.173234 -2.788813  0.193987
# 2025-07-19 -0.136465  1.595597 -0.486425  0.242111

# %%
df['20250718':'20250719']
# Out:
#                    A         B         C         D
# 2025-07-18 -0.505456  1.173234 -2.788813  0.193987
# 2025-07-19 -0.136465  1.595597 -0.486425  0.242111

# %%
df.loc['20250718']
# Out:
# A   -0.505456
# B    1.173234
# C   -2.788813
# D    0.193987
# Name: 2025-07-18 00:00:00, dtype: float64

# %%
df.loc['20250718', ['A', 'B']]
# Out:
# A   -0.505456
# B    1.173234
# Name: 2025-07-18 00:00:00, dtype: float64

# %%
df.loc['20250718':'20250719', ['A', 'B']]
# Out:
#                    A         B
# 2025-07-18 -0.505456  1.173234
# 2025-07-19 -0.136465  1.595597

# %%
df.loc[:, ['A','B']]
# Out:
#                    A         B
# 2025-07-17  1.332554 -0.208895
# 2025-07-18 -0.505456  1.173234
# 2025-07-19 -0.136465  1.595597
# 2025-07-20  0.725907  0.323068
# 2025-07-21  0.151433  1.252990
# 2025-07-22  1.404012 -0.124493

# %%
df.iloc[0,0]
# Out:
# np.float64(1.3325544034287817)

# %%
df.iloc[3]
# Out:
# A    0.725907
# B    0.323068
# C   -0.401490
# D    2.567489
# Name: 2025-07-20 00:00:00, dtype: float64
