# %% [markdown]
# # データの概要を確認する

# %%
import pandas as pd
customer_master = pd.read_csv('customer_master.csv')
customer_master.head()
# Out:
#   customer_id customer_name    registration_date customer_name_kana  \
# 0    IK152942        平田 裕次郎  2019-01-01 00:25:33          ひらた ゆうじろう
# 1    TS808488         田村 詩織  2019-01-01 01:13:45            たむら しおり
# 2    AS834628         久野 由樹  2019-01-01 02:00:14             ひさの ゆき
# 3    AS345469          鶴岡 薫  2019-01-01 04:48:22           つるおか かおる
# 4    GD892565         大内 高史  2019-01-01 04:54:51           おおうち たかし
#
#                          email gender  age      birth pref
# 0  hirata_yuujirou@example.com      M   29  1990/6/10  石川県
# 1    tamura_shiori@example.com      F   33  1986/5/20  東京都
# 2      hisano_yuki@example.com      F   63   1956/1/2  茨城県
# 3   tsuruoka_kaoru@example.com      M   74  1945/3/25  東京都
# 4   oouchi_takashi@example.com      M   54   1965/8/5  千葉県

# %%
item_master = pd.read_csv('item_master.csv')
item_master.head()
# Out:
#   item_id item_name  item_price
# 0    S001      PC-A       50000
# 1    S002      PC-B       85000
# 2    S003      PC-C      120000
# 3    S004      PC-D      180000
# 4    S005      PC-E      210000

# %% [markdown]
# # concatで2つのデータを1まとめに

# %%
transaction_1 = pd.read_csv('transaction_1.csv')
transaction_2 = pd.read_csv('transaction_2.csv')
transaction = pd.concat([transaction_1, transaction_2], ignore_index= True)
transaction.head()
# Out:
#   transaction_id   price         payment_date customer_id
# 0    T0000000113  210000  2019-02-01 01:36:57    PL563502
# 1    T0000000114   50000  2019-02-01 01:37:23    HD678019
# 2    T0000000115  120000  2019-02-01 02:34:19    HD298120
# 3    T0000000116  210000  2019-02-01 02:47:23    IK452215
# 4    T0000000117  170000  2019-02-01 04:33:46    PL542865

# %%
transaction_detail  = pd.concat([transaction_detail_1, transaction_detail_2], ignore_index= True)
transaction_detail.head()
# Out:
#    detail_id transaction_id item_id  quantity
# 0          0    T0000000113    S005         1
# 1          1    T0000000114    S001         1
# 2          2    T0000000115    S003         1
# 3          3    T0000000116    S005         1
# 4          4    T0000000117    S002         2

# %% [markdown]
# # トランザクションとマスタをJOINする

# %%
customer_transaction_join_data = pd.merge(transaction, customer_master, on='customer_id', how='left')
customer_transaction_join_data.head()
# Out:
#   transaction_id   price         payment_date customer_id customer_name  \
# 0    T0000000113  210000  2019-02-01 01:36:57    PL563502         井本 芳正
# 1    T0000000114   50000  2019-02-01 01:37:23    HD678019         三船 六郎
# 2    T0000000115  120000  2019-02-01 02:34:19    HD298120         山根 小雁
# 3    T0000000116  210000  2019-02-01 02:47:23    IK452215         池田 菜摘
# 4    T0000000117  170000  2019-02-01 04:33:46    PL542865         栗田 憲一
#
#      registration_date customer_name_kana                        email gender  \
# 0  2019-01-07 14:34:35           いもと よしまさ  imoto_yoshimasa@example.com      M
# 1  2019-01-27 18:00:11           みふね ろくろう   mifune_rokurou@example.com      M
# 2  2019-01-11 08:16:02            やまね こがん     yamane_kogan@example.com      M
# 3  2019-01-10 05:07:38            いけだ なつみ    ikeda_natsumi@example.com      F
# 4  2019-01-25 06:46:05           くりた けんいち   kurita_kenichi@example.com      M
#
#    age       birth pref
# 0   30   1989/7/15  熊本県
# ...

# %% [markdown]
# # 商品マスタと履歴の詳細をJOINする

# %%
item_detail_join_data = pd.merge(transaction_detail, item_master, on='item_id', how='left')
item_detail_join_data.head()
# Out:
#    detail_id transaction_id item_id  quantity item_name  item_price
# 0          0    T0000000113    S005         1      PC-E      210000
# 1          1    T0000000114    S001         1      PC-A       50000
# 2          2    T0000000115    S003         1      PC-C      120000
# 3          3    T0000000116    S005         1      PC-E      210000
# 4          4    T0000000117    S002         2      PC-B       85000
