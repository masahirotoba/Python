# %% [markdown]
# # ライブラリをインポート

# %%
import pandas as pd
from IPython.display import display

# %% [markdown]
# # 表示方法を設定する

# %%
# 小数点以下4桁で固定
pd.options.display.float_format = '{:.4f}'.format

# データフレームで全ての項目を表示
pd.set_option('display.max_columns', None)

# %% [markdown]
# # CSVをインポート（復習）

# %%
from google.colab import files
# CSVをアップロードする

# %%
# DataFrameに読み込む
# read_csv関数を使うと読み込める
df_csv = pd.read_csv('売上データ.csv')

# display関数で表示
df_csv.head()
# Out:
#    受注ID        日付  店舗 担当者     所属    企業  企業分類   商品   カテゴリ    単価    原価  数量  \
# 0     1  2022/1/1  東京  田中  第1営業部    企業   大企業  商品B  カテゴリX   750   700   1
# 1     2  2022/1/3  大阪  佐藤  第1営業部   D電機  零細企業  商品D  カテゴリY  3000  2750   4
# 2     3  2022/1/3  大阪  佐藤  第1営業部   B商事  中小企業  商品E  カテゴリZ  5000  4500   6
# 3     4  2022/1/5  大阪  田中  第1営業部  A自動車   大企業  商品A  カテゴリX   500   475   1
# 4     5  2022/1/5  大阪  山田  第2営業部   D電機  零細企業  商品E  カテゴリZ  5000  4500   1
#
#       売上
# 0    750
# 1  12000
# 2  30000
# 3    500
# 4   5000

# %%
# DataFrameに読み込む
# read_csv関数を使うと読み込める
df_excel = pd.read_excel('売上データ2.xlsx')

# display関数で表示
df_excel.head()
# Out:
#    受注ID         日付  数量     売上  店舗マスタ.店舗ID  企業マスタ.企業ID  担当者マスタ.担当者ID  \
# 0     1 2022-01-01   1    750           1           1             1
# 1     4 2022-01-03   1    500           2           1             1
# 2     2 2022-01-03   4  12000           2           4             2
# 3     6 2022-01-05   1   5000           3           4             2
# 4     3 2022-01-05   6  30000           2           2             2
#
#    商品マスタ.商品ID
# 0           2
# 1           1
# 2           4
# 3           5
# 4           5

# %% [markdown]
# # DataFrameを操作する

# %%
df_csv.head()
# Out:
#    受注ID        日付  店舗 担当者     所属    企業  企業分類   商品   カテゴリ    単価    原価  数量  \
# 0     1  2022/1/1  東京  田中  第1営業部    企業   大企業  商品B  カテゴリX   750   700   1
# 1     2  2022/1/3  大阪  佐藤  第1営業部   D電機  零細企業  商品D  カテゴリY  3000  2750   4
# 2     3  2022/1/3  大阪  佐藤  第1営業部   B商事  中小企業  商品E  カテゴリZ  5000  4500   6
# 3     4  2022/1/5  大阪  田中  第1営業部  A自動車   大企業  商品A  カテゴリX   500   475   1
# 4     5  2022/1/5  大阪  山田  第2営業部   D電機  零細企業  商品E  カテゴリZ  5000  4500   1
#
#       売上
# 0    750
# 1  12000
# 2  30000
# 3    500
# 4   5000

# %%
# 1列だけ出力する
display(df_csv['売上'])
# Out:
# 0         750
# 1       12000
# 2       30000
# 3         500
# 4        5000
#         ...
# 1134     3000
# 1135    10000
# 1136    15000
# 1137      500
# 1138     5000
# Name: 売上, Length: 1139, dtype: int64

# %%
# データ型はSeriesになるので注意
print(type(df_csv['売上']))
# Out:
# <class 'pandas.core.series.Series'>

# %% [markdown]
# # 2列出力するとDataFrameに

# %%
display(df_csv[['日付', '売上']])
# Out:
#               日付     売上
# 0       2022/1/1    750
# 1       2022/1/3  12000
# 2       2022/1/3  30000
# 3       2022/1/5    500
# 4       2022/1/5   5000
# ...          ...    ...
# 1134  2024/12/25   3000
# 1135  2024/12/28  10000
# 1136  2024/12/28  15000
# 1137  2024/12/31    500
# 1138  2024/12/31   5000
#
# [1139 rows x 2 columns]

# %%
df_csv[['日付', '売上']].head()
# Out:
#          日付     売上
# 0  2022/1/1    750
# 1  2022/1/3  12000
# 2  2022/1/3  30000
# 3  2022/1/5    500
# 4  2022/1/5   5000

# %%
print(type(df_csv[['日付', '売上']]))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# # 店舗が「東京」だけ出力

# %%
display(df_csv[df_csv['店舗'] == '東京'])
# Out:
#       受注ID          日付  店舗 担当者     所属     企業  企業分類   商品   カテゴリ    単価    原価  \
# 0        1    2022/1/1  東京  田中  第1営業部     企業   大企業  商品B  カテゴリX   750   700
# 9       10   2022/1/16  東京  佐藤  第1営業部    C工業  中小企業  商品A  カテゴリX   500   475
# 12      13   2022/1/18  東京  加藤  第2営業部    D電機  零細企業  商品E  カテゴリZ  5000  4500
# 16      17   2022/1/21  東京  佐藤  第1営業部   A自動車   大企業  商品B  カテゴリX   750   700
# 18      19   2022/1/25  東京  佐藤  第1営業部    C工業  中小企業  商品A  カテゴリX   500   475
# ...    ...         ...  ..  ..    ...    ...   ...  ...    ...   ...   ...
# 1116  1117  2024/12/10  東京  山田  第2営業部    D電機  零細企業  商品B  カテゴリX   750   700
# 1127  1128  2024/12/16  東京  山田  第2営業部    D電機  零細企業  商品D  カテゴリY  3000  2750
# 1134  1135  2024/12/25  東京  佐藤  第1営業部    C工業  中小企業  商品C  カテゴリY  1500   750
# 1135  1136  2024/12/28  東京  加藤  第2営業部  Eシステム  零細企業  商品E  カテゴリZ  5000  4500
# 1137  1138  2024/12/31  東京  田中  第1営業部    B商事  中小企業  商品A  カテゴリX   500   475
#
#       数量     売上
# 0      1    750
# 9      1    500
# ...

# %%
df_csv[df_csv['店舗'] == '東京'].head()
# Out:
#     受注ID         日付  店舗 担当者     所属    企業  企業分類   商品   カテゴリ    単価    原価  数量  \
# 0      1   2022/1/1  東京  田中  第1営業部    企業   大企業  商品B  カテゴリX   750   700   1
# 9     10  2022/1/16  東京  佐藤  第1営業部   C工業  中小企業  商品A  カテゴリX   500   475   1
# 12    13  2022/1/18  東京  加藤  第2営業部   D電機  零細企業  商品E  カテゴリZ  5000  4500   2
# 16    17  2022/1/21  東京  佐藤  第1営業部  A自動車   大企業  商品B  カテゴリX   750   700   5
# 18    19  2022/1/25  東京  佐藤  第1営業部   C工業  中小企業  商品A  カテゴリX   500   475   3
#
#        売上
# 0     750
# 9     500
# 12  10000
# 16   3750
# 18   1500

# %% [markdown]
# # 2つの条件を指定する

# %%
display(df_csv[(df_csv['店舗'] == '東京') & (df_csv['売上'] >= 500)])
# Out:
#       受注ID          日付  店舗 担当者     所属     企業  企業分類   商品   カテゴリ    単価    原価  \
# 0        1    2022/1/1  東京  田中  第1営業部     企業   大企業  商品B  カテゴリX   750   700
# 9       10   2022/1/16  東京  佐藤  第1営業部    C工業  中小企業  商品A  カテゴリX   500   475
# 12      13   2022/1/18  東京  加藤  第2営業部    D電機  零細企業  商品E  カテゴリZ  5000  4500
# 16      17   2022/1/21  東京  佐藤  第1営業部   A自動車   大企業  商品B  カテゴリX   750   700
# 18      19   2022/1/25  東京  佐藤  第1営業部    C工業  中小企業  商品A  カテゴリX   500   475
# ...    ...         ...  ..  ..    ...    ...   ...  ...    ...   ...   ...
# 1116  1117  2024/12/10  東京  山田  第2営業部    D電機  零細企業  商品B  カテゴリX   750   700
# 1127  1128  2024/12/16  東京  山田  第2営業部    D電機  零細企業  商品D  カテゴリY  3000  2750
# 1134  1135  2024/12/25  東京  佐藤  第1営業部    C工業  中小企業  商品C  カテゴリY  1500   750
# 1135  1136  2024/12/28  東京  加藤  第2営業部  Eシステム  零細企業  商品E  カテゴリZ  5000  4500
# 1137  1138  2024/12/31  東京  田中  第1営業部    B商事  中小企業  商品A  カテゴリX   500   475
#
#       数量     売上
# 0      1    750
# 9      1    500
# ...
